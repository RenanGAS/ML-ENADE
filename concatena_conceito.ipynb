# %%
import pandas as pd
import numpy as np

# %%
df_conceito = pd.read_csv('merge_tabelas_conceitos.csv')

# %%
df_conceito_faixa = df_conceito[['Nota_Conceito_Faixa']].copy()

# %%
df_conceito_faixa
# Out:
#       Nota_Conceito_Faixa
# 0                       3
# 1                       4
# 2                       4
# 3                       4
# 4                       4
# ...                   ...
# 5833                    3
# 5834                    2
# 5835                    4
# 5836                    5
# 5837                    5
#
# [5838 rows x 1 columns]

# %%
df_tabela_final = pd.read_csv('teste_OHE.csv')

# %%
df_tabela_final_treinamento = pd.concat([df_tabela_final, df_conceito_faixa], axis=1)

# %%
df_tabela_final_treinamento
# Out:
#       Numero_Notas_Invalidas  Numero_Faltantes  Numero_Participantes  \
# 0                   0.024390          0.097561              0.878049
# 1                   0.000000          0.241071              0.758929
# 2                   0.000000          0.171717              0.828283
# 3                   0.000000          0.210526              0.789474
# 4                   0.000000          0.085106              0.914894
# ...                      ...               ...                   ...
# 5833                0.016393          0.032787              0.950820
# 5834                0.000000          0.166667              0.833333
# 5835                0.000000          0.111111              0.888889
# 5836                0.000000          0.000000              1.000000
# 5837                0.000000          0.054054              0.945946
#
#       nulos_UF_Ensino_Medio       RO   AC        AM   RR        PA   AP  ...  \
# ...

# %%
df_tabela_final_treinamento.to_csv('./{}.csv'.format('teste_OHE_treinamento'),index=False)
