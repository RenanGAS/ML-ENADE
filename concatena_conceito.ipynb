# %%
import pandas as pd
import numpy as np

# %%
df_conceito = pd.read_csv('merge_tabelas_conceitos_Teste.csv')

# %%
df_conceito_faixa = df_conceito[['Nota_Conceito_Faixa']].copy()

# %%
df_conceito_faixa
# Out:
#       Nota_Conceito_Faixa
# 0                       3
# 1                       4
# 2                       4
# 3                       4
# 4                       4
# ...                   ...
# 5831                    3
# 5832                    2
# 5833                    4
# 5834                    5
# 5835                    5
#
# [5836 rows x 1 columns]

# %%
df_tabela_final = pd.read_csv('teste_OHE_curso_Teste.csv')

# %%
df_tabela_final_treinamento = pd.concat([df_tabela_final, df_conceito_faixa], axis=1)

# %%
df_tabela_final_treinamento
# Out:
#       Numero_Notas_Invalidas  Numero_Faltantes  Numero_Participantes  ADS  \
# 0                   0.024390          0.097561              0.878049  0.0
# 1                   0.000000          0.241071              0.758929  0.0
# 2                   0.000000          0.171717              0.828283  0.0
# 3                   0.000000          0.210526              0.789474  0.0
# 4                   0.000000          0.085106              0.914894  0.0
# ...                      ...               ...                   ...  ...
# 5831                0.016393          0.032787              0.950820  0.0
# 5832                0.000000          0.166667              0.833333  1.0
# 5833                0.000000          0.111111              0.888889  1.0
# 5834                0.000000          0.000000              1.000000  1.0
# 5835                0.000000          0.054054              0.945946  1.0
#
#       BCC   EC  GTI  LCC   RC   SI  ...  Não contribui  Não sei responder.4  \
# ...

# %%
df_tabela_final_treinamento.to_csv(f'./teste_OHE_curso_treinamento_Teste.csv',index=False)
