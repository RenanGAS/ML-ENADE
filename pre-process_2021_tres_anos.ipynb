# %% [markdown]
# ### **Tradução dos valores das características socioeconômicas da edição de 2021**

# %%
import pandas as pd
import numpy as np

# %%
dados_21 = pd.read_csv('computacao_enade_2021_tres_anos.csv')

# %%
dados_21.replace({'CO_GRUPO': {72: 'ADS', 4004: 'BCC', 6409: 'GTI', 4005: 'LCC', 79: 'RC', 4006: 'SI'}}, inplace=True) # inplace=True permite que o df seja modificado diretamente
dados_21 = dados_21.astype({'CO_GRUPO':str})

estado_dict = {
11 : 'RO',12 : 'AC', 
13 : 'AM',14 : 'RR',
15 : 'PA',16 : 'AP',
17 : 'TO',21 : 'MA',
22 : 'PI',23 : 'CE',
24 : 'RN',25 : 'PB',
26 : 'PE',27 : 'AL',
28 : 'SE',29 : 'BA',
31 : 'MG',32 : 'ES',
33 : 'RJ',35 : 'SP',
41 : 'PR',42 : 'SC',
43 : 'RS',50 : 'MS',
51 : 'MT',52 : 'GO', 
53 : 'DF'
}
dados_21['CO_UF_CURSO'].replace(estado_dict,inplace=True)
dados_21 = dados_21.astype({'CO_UF_CURSO':str})

regiao_dict = {
1 : 'N',2 : 'NE', 
3 : 'SE',4 : 'SUL',
5 : 'CO'
}
dados_21['CO_REGIAO_CURSO'].replace(regiao_dict,inplace=True)
dados_21 = dados_21.astype({'CO_REGIAO_CURSO':str})

# %% [markdown]
# #### **###################################################**
# #### **Análise de caso 1: IESes do tipo especial "6"**

# %%
# Não há IESes do tipo especial

# ies_especial = dados_21[dados_21["CO_CATEGAD"] == 6]
# ies_especial

# %% [markdown]
# #### **###################################################**

# %%
cat_adm_dict = {
1 : 'Pública Federal',2 : 'Pública Estadual', 
3 : 'Pública Municipal',4 : 'Privada CFL',
5 : 'Privada SFL'
}
dados_21['CO_CATEGAD'].replace(cat_adm_dict,inplace=True)
dados_21 = dados_21.astype({'CO_CATEGAD':str})

cat_org_dict = {
10019 : 'CEFET',10020 : 'Centro Universitário', 
10022 : 'Faculdade',10026 : 'IFECT',
10028 : 'Universidade'
}
dados_21['CO_ORGACAD'].replace(cat_org_dict,inplace=True)
dados_21 = dados_21.astype({'CO_ORGACAD':str})

turno_dict = {
1 : 'Matutino',2 : 'Vespertino', 
3 : 'Integral',4 : 'Noturno'
}
dados_21['CO_TURNO_GRADUACAO'].replace(turno_dict,inplace=True)
dados_21 = dados_21.astype({'CO_TURNO_GRADUACAO':str})

# %% [markdown]
# #### **###################################################**
# #### **Análise de caso 2: Outliers dos atributos ANO_FIM_EM e ANO_IN_GRAD**

# %%
# Análise dos atributos ANO_FIM_EM e ANO_IN_GRAD

outliers_afem = dados_21[(dados_21['ANO_FIM_EM'] < 1951) | (dados_21['ANO_FIM_EM'] > 2021)]
outliers_afem

outliers_aig = dados_21[(dados_21['ANO_IN_GRAD'] < 1971) | (dados_21['ANO_IN_GRAD'] > 2017)]
outliers_aig

media_afem = dados_21['ANO_FIM_EM'].mean()
media_afem

media_aig = dados_21['ANO_IN_GRAD'].mean()
media_aig

# %% [markdown]
# #### **###################################################**

# %%
# Atributo derivado 1 - DIF_GRAD_EM
dados_21["DIF_GRAD_EM"] = dados_21['ANO_IN_GRAD'] - dados_21['ANO_FIM_EM']

# Atributo derivado 2 - DIF_ANO_GRAD
dados_21["DIF_ANO_GRAD"] = (dados_21['NU_ANO'] - dados_21['ANO_IN_GRAD']) + 1

dados_21["ANO_FIM_EM"] = dados_21['NU_ANO'] - dados_21['ANO_FIM_EM']

# %%
est_civil_dict = {
'A' : 'Solteiro','B' : 'Casado', 
'C' : 'Separado', 'D' : 'Viúvo',
'E': 'Outro'
}
dados_21['QE_I01'].replace(est_civil_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I01':str})

raca_dict = {
'A' : 'Branca','B' : 'Preta', 
'C' : 'Amarela', 'D' : 'Parda',
'E': 'Indígena', 'F': 'Não declarado'
}
dados_21['QE_I02'].replace(raca_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I02':str})

nacionalidade_dict = {
'A' : 'Brasileira','B' : 'Naturalizada', 
'C' : 'Estrangeira'
}
dados_21['QE_I03'].replace(nacionalidade_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I03':str})

nl_pai_mae_dict = {
'A' : 'Nenhuma','B' : 'Fundamental 1-5', 
'C' : 'Fundamental 6-9', 'D' : 'Médio',
'E': 'Superior', 'F': 'Pós-graduação'
}
dados_21['QE_I04'].replace(nl_pai_mae_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I04':str})
dados_21['QE_I05'].replace(nl_pai_mae_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I05':str})

moradia_dict = {
'A' : 'Sozinho','B' : 'Parentes', 
'C' : 'Cônjuge/Filhos', 'D' : 'Outras pessoas',
'E': 'Universidade', 'F': 'Habitação individual/coletiva'
}
dados_21['QE_I06'].replace(moradia_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I06':str})

qtde_moradia_dict = {
'A' : 'Nenhuma','B' : 'Uma', 
'C' : 'Duas', 'D' : 'Três',
'E': 'Quatro', 'F': 'Cinco',
'G': 'Seis', 'H': 'Sete ou mais'
}
dados_21['QE_I07'].replace(qtde_moradia_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I07':str})

renda_dict = {
'A' : 'Até 1,5 SM','B' : 'De 1,5 a 3 SM', 
'C' : 'De 3 a 4,5 SM', 'D' : 'De 4,5 a 6 SM',
'E': 'De 6 a 10 SM', 'F': 'De 10 a 30 SM',
'G': 'Acima de 30 SM'
}
dados_21['QE_I08'].replace(renda_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I08':str})

status_financ_dict = {
'A' : 'Sem renda/Outros','B' : 'Sem renda/Outros', 
'C' : 'Tem renda/Outros', 'D' : 'Tem renda/Independente',
'E': 'Tem renda/Sustenta', 'F': 'Tem renda/Principal'
}
dados_21['QE_I09'].replace(status_financ_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I09':str})

trabalho_dict = {
'A' : 'Não','B' : 'Eventualmente',
'C' : 'Até 20 horas', 'D' : '21 a 39 horas',
'E': '40 horas ou mais'
}
dados_21['QE_I10'].replace(trabalho_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I10':str})

recebeu_bolsa_dict = {
'A' : 'Não se aplica','B' : 'Não',
'C' : 'Sim', 'D' : 'Sim',
'E': 'Sim', 'F' : 'Sim',
'G' : 'Sim', 'H' : 'Sim',
'I': 'Sim', 'J' : 'Sim',
'K' : 'Sim'
}
dados_21['QE_I11'].replace(recebeu_bolsa_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I11':str})

aux_permanencia_dict = {
'A' : 'Nenhum','B' : 'Moradia',
'C' : 'Alimentação', 'D' : 'Moradia e Alimentação',
'E': 'Permanência', 'F' : 'Outro'
}
dados_21['QE_I12'].replace(aux_permanencia_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I12':str})

bolsa_academica_dict = {
'A' : 'Nenhum','B' : 'IC',
'C' : 'Extensão', 'D' : 'Monitoria',
'E': 'PET', 'F' : 'Outro'
}
dados_21['QE_I13'].replace(bolsa_academica_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I13':str})

atividades_exterior_dict = {
'A' : 'Não','B' : 'Prog CSF',
'C' : 'Prog Inter GF', 'D' : 'Prog Inter GE',
'E': 'Prog Inter Inst', 'F' : 'Prog Inter Outro'
}
dados_21['QE_I14'].replace(atividades_exterior_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I14':str})

politica_dict = {
'A' : 'Não','B' : 'Critério étnico-racial',
'C' : 'Critério de renda', 'D' : 'Bolsa de estudos',
'E': 'Combinação de critérios', 'F': 'Critérios diferentes'
}
dados_21['QE_I15'].replace(politica_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I15':str})

uf_em_dict = {
11 : 'RO',12 : 'AC', 
13 : 'AM',14 : 'RR',
15 : 'PA',16 : 'AP',
17 : 'TO',21 : 'MA',
22 : 'PI',23 : 'CE',
24 : 'RN',25 : 'PB',
26 : 'PE',27 : 'AL',
28 : 'SE',29 : 'BA',
31 : 'MG',32 : 'ES',
33 : 'RJ',35 : 'SP',
41 : 'PR',42 : 'SC',
43 : 'RS',50 : 'MS',
51 : 'MT',52 : 'GO', 
53 : 'DF',99 : 'Não se aplica'
}
dados_21['QE_I16'].replace(uf_em_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I16':str})

tipo_em_dict = {
'A' : 'Pública','B' : 'Privada', 
'C' : 'Exterior', 'D' : 'Pública',
'E' : 'Privada', 'F' : 'Exterior'
}
dados_21['QE_I17'].replace(tipo_em_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I17':str})

mod_em_dict = {
'A' : 'Tradicional','B' : 'Técnico', 
'C' : 'Magistério', 'D' : 'Supletivo',
'E':'Outra'
}
dados_21['QE_I18'].replace(mod_em_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I18':str})

incentivo_graduacao_dict = {
'A' : 'Ninguem','B' : 'Pais', 
'C' : 'Outros Família', 'D' : 'Professores',
'E':'Líder religioso', 'F':'Colegas',
'G':'Outros'
}
dados_21['QE_I19'].replace(incentivo_graduacao_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I19':str})

enfrentar_diff_dict = {
'A' : 'Sem dificuldade','B' : 'Sem apoio', 
'C' : 'Pais', 'D' : 'Avós',
'E':'Irmãos/Primos/Tios', 'F':'Líder religioso',
'G':'Colegas de curso', 'H':'Professores do curso',
'I':'Serviço de apoio', 'J':'Colegas de trabalho',
'K':'Outro'
}
dados_21['QE_I20'].replace(enfrentar_diff_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I20':str})

familia_superior_dict = {
'A' : 'Sim','B' : 'Não'
}
dados_21['QE_I21'].replace(familia_superior_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I21':str})

qtde_livros_dict = {
'A' : 'Nenhum','B' : '1 ou 2',
'C' : '3-5', 'D' : '6-8',
'E': '+8'
}
dados_21['QE_I22'].replace(qtde_livros_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I22':str})

horas_estudo_dict = {
'A' : 'Nenhum','B' : '1-3',
'C' : '4-7', 'D' : '8-12',
'E': '+12'
}
dados_21['QE_I23'].replace(horas_estudo_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I23':str})

idioma_estrangeiro_dict = {
'A' : 'Sim presencial','B' : 'Sim semi.',
'C' : 'Sim pres. e semi.', 'D' : 'Sim distância',
'E': 'Não'
}
dados_21['QE_I24'].replace(idioma_estrangeiro_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I24':str})

motivo_curso_dict = {
'A' : 'Mercado','B' : 'Família',
'C' : 'Valorização', 'D' : 'Prestígio',
'E': 'Vocação', 'F': 'EaD',
'G': 'Baixa concor.', 'H': 'Outro'
}
dados_21['QE_I25'].replace(motivo_curso_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I25':str})

motivo_ies_dict = {
'A' : 'Gratuidade','B' : 'Mensalidade',
'C' : 'Prox. residência', 'D' : 'Prox. trabalho',
'E': 'Facilidade acesso', 'F': 'Qualidade',
'G': 'Aprovação', 'H': 'Bolsa',
'I': 'Outro'
}
dados_21['QE_I26'].replace(motivo_ies_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I26':str})

alternativas_27_68_dict = {
    1 : 'Disc. totalmente',
    2 : 'Discordo',
    3 : 'Disc. parc.',
    4 : 'Concordo parc.',
    5 : 'Concordo',
    6 : 'Concordo Total.',
    7 : 'Não sei responder',
    8 : 'Não se aplica'
}
dados_21['QE_I27'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I27':str})

dados_21['QE_I28'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I28':str})

dados_21['QE_I29'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I29':str})

dados_21['QE_I30'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I30':str})

dados_21['QE_I31'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I31':str})

dados_21['QE_I32'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I32':str})

dados_21['QE_I33'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I33':str})

dados_21['QE_I34'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I34':str})

dados_21['QE_I35'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I35':str})

dados_21['QE_I36'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I36':str})

dados_21['QE_I37'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I37':str})

dados_21['QE_I38'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I38':str})

dados_21['QE_I39'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I39':str})

dados_21['QE_I40'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I40':str})

dados_21['QE_I41'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I41':str})

dados_21['QE_I42'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I42':str})

dados_21['QE_I43'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I43':str})

dados_21['QE_I44'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I44':str})

dados_21['QE_I45'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I45':str})

dados_21['QE_I46'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I46':str})

dados_21['QE_I47'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I47':str})

dados_21['QE_I48'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I48':str})

dados_21['QE_I49'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I49':str})

dados_21['QE_I50'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I50':str})

dados_21['QE_I51'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I51':str})

dados_21['QE_I52'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I52':str})

dados_21['QE_I53'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I53':str})

dados_21['QE_I54'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I54':str})

dados_21['QE_I55'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I55':str})

dados_21['QE_I56'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I56':str})

dados_21['QE_I57'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I57':str})

dados_21['QE_I58'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I58':str})

dados_21['QE_I59'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I59':str})

dados_21['QE_I60'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I60':str})

dados_21['QE_I61'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I61':str})

dados_21['QE_I62'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I62':str})

dados_21['QE_I63'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I63':str})

dados_21['QE_I64'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I64':str})

dados_21['QE_I65'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I65':str})

dados_21['QE_I66'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I66':str})

dados_21['QE_I67'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I67':str})

dados_21['QE_I68'].replace(alternativas_27_68_dict,inplace=True)
dados_21 = dados_21.astype({'QE_I68':str})

# %% [markdown]
# #################################################
# #### **Geração de código para questões repetidas**

# %%
for i in range(63, 69):
    print(f"dados_21['QE_I{i}'].replace(alternativas_27_68_dict,inplace=True)\ndados_21 = dados_21.astype("+"{"+f"'QE_I{i}':str"+"})\n")

# %% [markdown]
# #### **Geração de entradas para o dicionário de colunas**

# %%
for i in range(63, 69):
    print(f'    "QE_I{i}": "",')

# %% [markdown]
# #################################################

# %%
columns_dict = {
    "NU_ANO": "Ano",
    "CO_CURSO": "Codigo_do_Curso",
    "CO_GRUPO": "Curso",
    "CO_UF_CURSO": "UF",
    "CO_REGIAO_CURSO": "Regiao",
    "CO_CATEGAD": "Cat_Administrativa",
    "CO_ORGACAD": "Cat_Org_Academica",
    "CO_TURNO_GRADUACAO": "Turno",
    "TP_PRES": "Tipo_Presenca",
    "NT_FG": "Nota_FG",
    "NT_CE": "Nota_CE",
    "DIF_GRAD_EM": "Anos_Preparacao",
    "DIF_ANO_GRAD": "Anos_Graduacao",
    "ANO_FIM_EM": "Conclusao_Ensino_Medio",
    "ANO_IN_GRAD": "Inicio_Graduacao",
    "NU_IDADE": "Idade",
    "TP_SEXO": "Sexo",
    "QE_I01": "Estado_Civil",
    "QE_I02": "Cor_Raca",
    "QE_I03": "Nacionalidade",
    "QE_I04": "Nl_Pai",
    "QE_I05": "Nl_Mae",
    "QE_I06": "Moradia",
    "QE_I07": "Qtde_Pessoas",
    "QE_I08": "Renda",
    "QE_I09": "Situacao_Financeira",
    "QE_I10": "Situacao_Trabalho",
    "QE_I11": "Bolsa_de_Estudos",
    "QE_I12": "Auxilio_Permanencia",
    "QE_I13": "Bolsa_Academica",
    "QE_I14": "Atividade_Exterior",
    "QE_I15": "Politica_de_Ingresso",
    "QE_I16": "UF_Ensino_Medio",
    "QE_I17": "Tipo_Escola_EM",
    "QE_I18": "Modalidade_EM",
    "QE_I19": "Incentivo_Grad",
    "QE_I20": "Enfrentar_Diff",
    "QE_I21": "Familia_Superior",
    "QE_I22": "Qtde_Livros",
    "QE_I23": "Horas_de_Estudo",
    "QE_I24": "Idioma_Estrangeiro",
    "QE_I25": "Motivo_Curso",
    "QE_I26": "Motivo_IES",
    "QE_I27": "Formacao",
    "QE_I28": "Contribuicao_Disciplinas",
    "QE_I29": "Eficiencia_Metodologias",
    "QE_I30": "Experiencias_Inovadoras",
    "QE_I31": "Consciencia_Etica",
    "QE_I32": "Trabalho_Em_Equipe",
    "QE_I33": "Capacidade_Reflexao",
    "QE_I34": "Desenv_Solucao_Problemas",
    "QE_I35": "Comunicacao_Oral_Escrita",
    "QE_I36": "Capacidade_Aprendizado",
    "QE_I37": "Estimulo_Professor",
    "QE_I38": "Plano_de_Ensino",
    "QE_I39": "Contribuicao_Referencias",
    "QE_I40": "Oportunidades_Superacao",
    "QE_I41": "Orientacao_Academica",
    "QE_I42": "Exigencia_Organizacao",
    "QE_I43": "Oportunidades_Extensao",
    "QE_I44": "Oportunidades_IC",
    "QE_I45": "Participacao_Eventos",
    "QE_I46": "Representantes_Orgaos",
    "QE_I47": "Atividades_Praticas",
    "QE_I48": "Eficiencia_Atv_Praticas",
    "QE_I49": "Conhecimentos_Atualizados",
    "QE_I50": "Eficiencia_Estagio",
    "QE_I51": "Eficiencia_TCC",
    "QE_I52": "Intercambio_Nacional",
    "QE_I53": "Intercambio_Internacional",
    "QE_I54": "Avaliacoes_Periodicas",
    "QE_I55": "Avaliacoes_Adequadas",
    "QE_I56": "Disponibilidade_Professores",
    "QE_I57": "Dominio_Professores",
    "QE_I58": "Uso_TICs",
    "QE_I59": "Suficiencia_Funcionarios",
    "QE_I60": "Disp_Monitores",
    "QE_I61": "Condicao_Salas",
    "QE_I62": "Condicao_Praticas",
    "QE_I63": "Amb_Equip_Adequados",
    "QE_I64": "Eficiencia_Biblioteca",
    "QE_I65": "Uso_Biblio_Virtual",
    "QE_I66": "Respeito_Diversidade",
    "QE_I67": "Atv_Lazer_Social",
    "QE_I68": "Atendimento_Necessidades"
}
dados_21.rename(columns = columns_dict, inplace = True)
dados_21 = dados_21.reindex(columns=["Ano","Codigo_do_Curso","Curso","UF","Regiao","Cat_Administrativa","Cat_Org_Academica","Turno",
                                     "Tipo_Presenca","Nota_FG","Nota_CE","Anos_Preparacao","Anos_Graduacao","Conclusao_Ensino_Medio",
                                     "Inicio_Graduacao","Idade","Sexo","Estado_Civil","Cor_Raca","Nacionalidade","Nl_Pai","Nl_Mae",
                                     "Moradia","Qtde_Pessoas","Renda","Situacao_Financeira","Situacao_Trabalho","Bolsa_de_Estudos",
                                     "Auxilio_Permanencia","Bolsa_Academica","Atividade_Exterior","Politica_de_Ingresso","UF_Ensino_Medio",
                                     "Tipo_Escola_EM","Modalidade_EM","Incentivo_Grad","Enfrentar_Diff","Familia_Superior","Qtde_Livros",
                                     "Horas_de_Estudo","Idioma_Estrangeiro","Motivo_Curso","Motivo_IES","Formacao","Contribuicao_Disciplinas",
                                     "Eficiencia_Metodologias","Experiencias_Inovadoras","Consciencia_Etica","Trabalho_Em_Equipe",
                                     "Capacidade_Reflexao","Desenv_Solucao_Problemas","Comunicacao_Oral_Escrita","Capacidade_Aprendizado",
                                     "Estimulo_Professor","Plano_de_Ensino","Contribuicao_Referencias","Oportunidades_Superacao",
                                     "Orientacao_Academica","Exigencia_Organizacao","Oportunidades_Extensao","Oportunidades_IC",
                                     "Participacao_Eventos","Representantes_Orgaos","Atividades_Praticas","Eficiencia_Atv_Praticas",
                                     "Conhecimentos_Atualizados","Eficiencia_Estagio","Eficiencia_TCC","Intercambio_Nacional",
                                     "Intercambio_Internacional","Avaliacoes_Periodicas","Avaliacoes_Adequadas","Disponibilidade_Professores",
                                     "Dominio_Professores","Uso_TICs","Suficiencia_Funcionarios","Disp_Monitores","Condicao_Salas",
                                     "Condicao_Praticas","Amb_Equip_Adequados","Eficiencia_Biblioteca","Uso_Biblio_Virtual",
                                     "Respeito_Diversidade","Atv_Lazer_Social","Atendimento_Necessidades"])

# %%
dados_21.to_csv('./{}.csv'.format('pre-process_2021_tres_anos'),index=False)

# %% [markdown]
# #### **Gráfico do número de alunos de cada curso**

# %%
count_bcc = dados_21[dados_21['Curso'] == 'BCC']['Curso'].count()
count_ads = dados_21[dados_21['Curso'] == 'ADS']['Curso'].count()
count_gti = dados_21[dados_21['Curso'] == 'GTI']['Curso'].count()
count_ec = dados_21[dados_21['Curso'] == 'EC']['Curso'].count()
count_lcc = dados_21[dados_21['Curso'] == 'LCC']['Curso'].count()
count_rc = dados_21[dados_21['Curso'] == 'RC']['Curso'].count()
count_si = dados_21[dados_21['Curso'] == 'SI']['Curso'].count()

count_array = [count_bcc,count_ads, count_gti, count_ec, 
               count_lcc, count_rc, count_si]

count_courses = pd.DataFrame({'Número de alunos': count_array}, index=['BCC', 'ADS', 'GTI', 'EC', 'LCC', 'RC', 'SI'])

count_courses.plot.bar();
