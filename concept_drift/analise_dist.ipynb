# %% [markdown]
# # Análise das distribuições para resultados

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
conjunto_1 = pd.read_csv('./criterios_divisao/cursos_grad_publicos_universidade_2017.csv')
conjunto_2 = pd.read_csv('./criterios_divisao/cursos_grad_publicos_universidade_2021.csv')

# %%
conjunto_1["F_Sexo"].describe()
# Out:
# count    280.000000
# mean       0.173688
# std        0.129987
# min        0.000000
# 25%        0.085714
# 50%        0.150581
# 75%        0.222222
# max        0.888889
# Name: F_Sexo, dtype: float64

# %%
conjunto_2["F_Sexo"].describe()
# Out:
# count    218.000000
# mean       0.150284
# std        0.099950
# min        0.000000
# 25%        0.083333
# 50%        0.131266
# 75%        0.200000
# max        0.500000
# Name: F_Sexo, dtype: float64

# %%
plt.hist(conjunto_1["F_Sexo"], bins=50, range=(0, 1), rwidth=0.8, label='2017', alpha=.8, edgecolor='red', density=True)
plt.hist(conjunto_2["F_Sexo"], bins=50, range=(0, 1), rwidth=0.8, label='2021', alpha=.7, edgecolor='yellow', density=True)
plt.legend()
plt.xlabel('F_Sexo')
plt.ylabel('Porcentagem')
plt.show()

# %%
conjunto_1["M_Sexo"].describe()
# Out:
# count    280.000000
# mean       0.826312
# std        0.129987
# min        0.111111
# 25%        0.777778
# 50%        0.849419
# 75%        0.914286
# max        1.000000
# Name: M_Sexo, dtype: float64

# %%
conjunto_2["M_Sexo"].describe()
# Out:
# count    218.000000
# mean       0.849716
# std        0.099950
# min        0.500000
# 25%        0.800000
# 50%        0.868734
# 75%        0.916667
# max        1.000000
# Name: M_Sexo, dtype: float64

# %%
plt.hist(conjunto_1["M_Sexo"], bins=50, range=(0, 1), rwidth=0.8, label='2017', alpha=.8, edgecolor='red', density=True)
plt.hist(conjunto_2["M_Sexo"], bins=50, range=(0, 1), rwidth=0.8, label='2021', alpha=.7, edgecolor='yellow', density=True)
plt.legend()
plt.xlabel('M_Sexo')
plt.ylabel('Porcentagem')
plt.show()

# %%
conjunto_1 = pd.read_csv('./criterios_divisao/cursos_grad_publicos_BCC_2011.csv')
conjunto_2 = pd.read_csv('./criterios_divisao/cursos_grad_publicos_BCC_2014.csv')

# %%
conjunto_1["Amplamente_Plano_de_Ensino"].describe()
# Out:
# count    108.000000
# mean       0.553903
# std        0.217691
# min        0.000000
# 25%        0.403797
# 50%        0.569048
# 75%        0.724986
# max        1.000000
# Name: Amplamente_Plano_de_Ensino, dtype: float64

# %%
conjunto_2["Amplamente_Plano_de_Ensino"].describe()
# Out:
# count    98.000000
# mean      0.460107
# std       0.179403
# min       0.000000
# 25%       0.334821
# 50%       0.452273
# 75%       0.565625
# max       1.000000
# Name: Amplamente_Plano_de_Ensino, dtype: float64

# %%
plt.hist(conjunto_1["Amplamente_Plano_de_Ensino"], bins=50, range=(0, 1), rwidth=0.8, label='2011', alpha=.8, edgecolor='red', density=True)
plt.hist(conjunto_2["Amplamente_Plano_de_Ensino"], bins=50, range=(0, 1), rwidth=0.8, label='2014', alpha=.7, edgecolor='yellow', density=True)
plt.legend()
plt.xlabel('Amplamente_Plano_de_Ensino')
plt.ylabel('Porcentagem')
plt.show()

# %%
conjunto_1 = pd.read_csv('./criterios_divisao/cursos_grad_publicos_2011.csv')
conjunto_2 = pd.read_csv('./criterios_divisao/cursos_grad_publicos_2021.csv')

# %%
conjunto_1 = pd.read_csv('./criterios_divisao/cursos_grad_privados_2011.csv')
conjunto_2 = pd.read_csv('./criterios_divisao/cursos_grad_privados_2021.csv')

# %%
conjunto_1["Nota_Conceito_Faixa"].describe()
# Out:
# count    1110.000000
# mean        2.796396
# std         0.877525
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: Nota_Conceito_Faixa, dtype: float64

# %%
conjunto_2["Nota_Conceito_Faixa"].describe()
# Out:
# count    1028.000000
# mean        2.661479
# std         0.859221
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         5.000000
# Name: Nota_Conceito_Faixa, dtype: float64

# %%
plt.hist(conjunto_1["Nota_Conceito_Faixa"], bins=5, range=(0, 5), rwidth=0.8, label='2011', alpha=.8, edgecolor='red', density=True)
plt.hist(conjunto_2["Nota_Conceito_Faixa"], bins=5, range=(0, 5), rwidth=0.8, label='2021', alpha=.7, edgecolor='yellow', density=True)
plt.legend()
plt.xlabel('Nota_Conceito_Faixa')
plt.ylabel('Porcentagem')
plt.show()

# %%
plt.hist(conjunto_1["Nota_Conceito_Faixa"], bins=5, range=(0, 5), rwidth=0.8, label='2011', alpha=.8, edgecolor='red', density=True)
plt.hist(conjunto_2["Nota_Conceito_Faixa"], bins=5, range=(0, 5), rwidth=0.8, label='2021', alpha=.7, edgecolor='yellow', density=True)
plt.legend()
plt.xlabel('Nota_Conceito_Faixa')
plt.ylabel('Porcentagem')
plt.show()
