# %% [markdown]
# ## Análise dos métodos de detecção de Data drift da biblioteca Deepchecks

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns1

# %% [markdown]
# ### Feature Drift

# %%
enade_treino = pd.read_csv("../../concept_drift/tabela_final_2017_treinamento.csv")
print(enade_treino["Nenhum"].mean())
print(len(enade_treino["Nenhum"]))
# Out:
# 0.18144558145661685
# 1605

# %%
enade_teste = pd.read_csv("../../concept_drift/tabela_final_2021_treinamento.csv")
print(enade_teste["Nenhum"].mean())
print(len(enade_teste["Nenhum"]))
# Out:
# 0.2495519115408349
# 1506

# %%
#fig, ax = plt.subplots()
#sns.ecdfplot(enade_treino["Numero_Participantes"], ax=ax)
#ax2 = ax.twinx()
#sns.ecdfplot(enade_teste["Numero_Participantes"], ax=ax2, color='r')
#plt.show()

# %% [markdown]
# ### Notas
#
# - Quero plotar a função de probabilidade de se ter uma determinada porcentagem numa questão
#     - Deste modo, não podemos ter uma soma geral maior que 1, como está sendo obtido

# %%
teste = sns.ecdfplot(enade_teste["Nenhum"]).get_lines()[0].get_data()

# %%
treino = sns1.ecdfplot(enade_treino["Nenhum"]).get_lines()[0].get_data()

# %%
data_points_teste = sns.ecdfplot(enade_teste["Nenhum"]).get_lines()[0].get_data()[0]

# %%
data_points_treino = sns.ecdfplot(enade_treino["Nenhum"]).get_lines()[0].get_data()[0]

# %%
common_set = set(data_points_teste) & set(data_points_treino)

# %%
common_set

# %%
max = 0

for i in common_set:
    #print(i)
    index_teste = np.where(teste[0] == i)[0][0]
    #print(index_teste[0][0])
    index_treino = np.where(treino[0] == i)[0][0]
    #print(index_treino)
    
    diff = teste[1][index_teste] - treino[1][index_treino]
    
    if diff < 0:
        diff = diff * -1
   
    if diff > max:
        max = diff

print(max)
# Out:
# 0.24864405307120424
