# %% [markdown]
# ## Label Drift

# %%
import numpy as np
import pandas as pd

from deepchecks.tabular import Dataset
from deepchecks.tabular.checks import LabelDrift

# %% [markdown]
# ### Carregamento dos dados de 2017 e 2021

# %%
enade_treino = pd.read_csv("../concept_drift/tabela_final_2017_treinamento.csv")
enade_teste = pd.read_csv("../concept_drift/tabela_final_2021_treinamento.csv")

# %%
train_dataset = Dataset(enade_treino, label='Nota_Conceito_Faixa', cat_features=[])
test_dataset = Dataset(enade_teste, label='Nota_Conceito_Faixa', cat_features=[])

# %% [markdown]
# ### Uso do método LabelDrift da biblioteca

# %%
check = LabelDrift()
result = check.run(train_dataset=train_dataset, test_dataset=test_dataset)

# %%
result
# Out:
# VBox(children=(HTML(value='<h4><b>Label Drift</b></h4>'), HTML(value='<p>    Calculate label drift between tra…

# %% [markdown]
# ## Feature Drift

# %%
from deepchecks.tabular.checks import FeatureDrift
from sklearn.svm import SVC

# %% [markdown]
# ### Carregamento dos dados de 2017 e 2021

# %%
enade_treino = pd.read_csv("../concept_drift/tabela_final_2017_treinamento.csv")

numero_caracteristicas = enade_treino.shape[1] - 1
X_enade_treino = enade_treino.iloc[:, 0:numero_caracteristicas]
y_enade_treino = enade_treino.iloc[:, -1]

enade_teste = pd.read_csv("../concept_drift/tabela_final_2021_treinamento.csv")

# %%
train_dataset = Dataset(enade_treino, label='Nota_Conceito_Faixa', cat_features=[])
test_dataset = Dataset(enade_teste, label='Nota_Conceito_Faixa', cat_features=[])

# %% [markdown]
# ### Uso do método FeatureDrift da biblioteca

# %% [markdown]
# #### Instanciação do modelo de preferência

# %%
model = SVC(probability=True)
model.fit(X_enade_treino, y_enade_treino)
# Out:
# SVC(probability=True)

# %% [markdown]
# #### Uso do método

# %%
check = FeatureDrift()
result = check.run(train_dataset=train_dataset, test_dataset=test_dataset, model=model, feature_importance_force_permutation=True)
# Out:
# deepchecks - WARNING - Features importance was not calculated:
# Skipping permutation importance calculation: calculation was projected to finish in 2443 seconds, but timeout was configured to 120 seconds

# %%
result.value
# Out:
# {'Numero_Notas_Invalidas': {'Drift score': 0.025273361383127857,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Numero_Faltantes': {'Drift score': 0.21466036166859048,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Numero_Participantes': {'Drift score': 0.2159883829169304,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'nulos_UF_Ensino_Medio': {'Drift score': 0.06870462076925937,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'RO': {'Drift score': 0.009352000099291269,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'AC': {'Drift score': 0.006131238286728458,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'AM': {'Drift score': 0.010171153392659837,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'RR': {'Drift score': 0.006295068945402216,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'PA': {'Drift score': 0.017740874508197724,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'AP': {'Drift score': 0.005820952948331293,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'TO': {'Drift score': 0.005165630313636482,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'MA': {'Drift score': 0.01587543905375388,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'PI': {'Drift score': 0.019771381762668905,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'CE': {'Drift score': 0.031138995420188387,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  

#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Maior parte': {'Drift score': 0.05741644015836965,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Alguns': {'Drift score': 0.07219967482096534,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Nenhum.1': {'Drift score': 0.02063149272070597,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Não sei responder': {'Drift score': 0.1050365516128633,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'nulos_Dominio_Professores': {'Drift score': 0.06870462076925937,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Todos.1': {'Drift score': 0.11114793163793427,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Maior parte.1': {'Drift score': 0.1042993136488315,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Alguns.1': {'Drift score': 0.07140906777872935,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Nenhum.2': {'Drift score': 0.02001216318526522,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Não sei responder.1': {'Drift score': 0.11036477144381973,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'nulos_Condicao_Salas': {'Drift score': 0.06870462076925937,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Nenhuma.4': {'Drift score': 0.11713767981035361,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Algumas': {'Drift score': 0.1295081356815727,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Maior parte.2': {'Drift score': 0.0668714549900088,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Todas': {'Drift score': 0.10032517903464026,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Não sei responder.2': {'Drift score': 0.21154013230566826,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'nulos_Condicao_Praticas': {'Drift score': 0.06870462076925937,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Nenhuma.5': {'Drift score': 0.07113229325687898,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Algumas.1': {'Drift score': 0.09030544488711822,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Maior parte.3': {'Drift score': 0.05578930384381475,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Todas.1': {'Drift score': 0.07076615655757032,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Não sei responder.3': {'Drift score': 0.20071737970237424,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'nulos_Plano_de_Ensino': {'Drift score': 0.06870462076925937,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Amplamente': {'Drift score': 0.06144394385076524,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Parcialmente': {'Drift score': 0.05697955840190641,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Muito pouco': {'Drift score': 0.036516860905288495,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Não contribui': {'Drift score': 0.033333333333333326,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Não sei responder.4': {'Drift score': 0.08321108091000484,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'nulos_Formacao': {'Drift score': 0.06870462076925937,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Muito boa': {'Drift score': 0.06507428231001233,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Boa': {'Drift score': 0.0799803899666133,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Regular': {'Drift score': 0.05816981295999801,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Fraca': {'Drift score': 0.026996065581909146,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Muito fraca': {'Drift score': 0.033313475071675924,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None},
#  'Não sei responder.5': {'Drift score': 0.10772734606744361,
#   'Method': 'Kolmogorov-Smirnov',
#   'Importance': None}}

# %%
result.show()
# Out:
# VBox(children=(HTML(value='<h4><b>Feature Drift</b></h4>'), HTML(value='<p>    Calculate drift between train d…

# %% [markdown]
# ## Multivariate Drift

# %%
from deepchecks.tabular.checks import MultivariateDrift

# %%
enade_treino = pd.read_csv("../concept_drift/tabela_final_2017_treinamento.csv")

numero_caracteristicas = enade_treino.shape[1] - 1
X_enade_treino = enade_treino.iloc[:, 0:numero_caracteristicas]
y_enade_treino = enade_treino.iloc[:, -1]

enade_teste = pd.read_csv("../concept_drift/tabela_final_2021_treinamento.csv")

# %%
train_dataset = Dataset(enade_treino, label='Nota_Conceito_Faixa', cat_features=[])
test_dataset = Dataset(enade_teste, label='Nota_Conceito_Faixa', cat_features=[])

# %%
check = MultivariateDrift()
result = check.run(train_dataset=train_dataset, test_dataset=test_dataset)

# %%
result.value

# %%
result.show()
# Out:
# VBox(children=(HTML(value='<h4><b>Multivariate Drift</b></h4>'), HTML(value='<p>    Calculate drift between th…
