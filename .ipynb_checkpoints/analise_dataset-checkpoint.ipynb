# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
dados_enade = pd.read_csv('tabela_final_analise_conceito.csv')

# %%
anos_enade = [2021, 2017, 2014, 2011]
df_2021 = pd.DataFrame()
df_2017 = pd.DataFrame()
df_2014 = pd.DataFrame()
df_2011 = pd.DataFrame()

for ano in anos_enade:
    subconjunto_ano = dados_enade.loc[dados_enade['Ano'] == ano]
    subconjunto_ano = subconjunto_ano.reset_index(drop=True)
    if ano == 2021:
        df_2021 = subconjunto_ano
    elif ano == 2017:
        df_2017 = subconjunto_ano
    elif ano == 2014:
        df_2014 = subconjunto_ano
    elif ano == 2011:
        df_2011 = subconjunto_ano

# %%
df_2021
# Out:
#        Ano  Numero_Notas_Invalidas  Numero_Faltantes  Numero_Participantes  \
# 0     2021                       1                 4                    36
# 1     2021                       0                27                    85
# 2     2021                       0                17                    82
# 3     2021                       0                12                    45
# 4     2021                       0                 4                    43
# ...    ...                     ...               ...                   ...
# 1501  2021                       0                 2                     8
# 1502  2021                       0                 4                    11
# 1503  2021                       0                 0                     8
# 1504  2021                       0                 3                    22
# 1505  2021                       0                 1                    34
#
#       ADS  BCC  EC  GTI  LCC  RC  ...  Não contribui  Não sei responder.4  \
# 0       0   41   0    0    0   0  ...              7                    2
# 1       0  112   0    0    0   0  ...             15                    3
# 2       0   99   0    0    0   0  ...              4                    0
# 3       0   57   0    0    0   0  ...              1                    2
# 4       0   47   0    0    0   0  ...              1                    0
# ...   ...  ...  ..  ...  ...  ..  ...            ...                  ...
# 1501    0    0   0    0    0  10  ...              0                    0
# 1502   15    0   0    0    0   0  ...              1                    0
# 1503    8    0   0    0    0   0  ...              0                    0
# 1504    0    0   0   25    0   0  ...              2                    0
# 1505   35    0   0    0    0   0  ...              7                    0
#
#       nulos_Formacao  Muito boa  Boa  Regular  Fraca  Muito fraca  \
# 0                  3          5   12       14      5            1
# 1                 11         25   28       38      5            2
# 2                 14         28   36       20      1            0
# 3                  0         19   21       15      2            0
# 4                  3         21   17        6      0            0
# ...              ...        ...  ...      ...    ...          ...
# 1501               2          3    2        3      0            0
# 1502               3          8    1        3      0            0
# 1503               0          3    4        1      0            0
# 1504               3          6    9        6      1            0
# 1505               0         11    7       11      6            0
#
#       Não sei responder.5  Nota_Conceito_Faixa
# 0                       1                    3
# 1                       3                    4
# 2                       0                    4
# 3                       0                    4
# 4                       0                    4
# ...                   ...                  ...
# 1501                    0                    3
# 1502                    0                    4
# 1503                    0                    3
# 1504                    0                    4
# 1505                    0                    3
#
# [1506 rows x 227 columns]

# %%
df_2017
# Out:
#        Ano  Numero_Notas_Invalidas  Numero_Faltantes  Numero_Participantes  \
# 0     2017                       0                 1                    22
# 1     2017                       0                21                    58
# 2     2017                       0                 8                    31
# 3     2017                       0                12                    53
# 4     2017                       0                 0                    26
# ...    ...                     ...               ...                   ...
# 1600  2017                       0                 0                    18
# 1601  2017                       0                 1                    14
# 1602  2017                       0                 0                     3
# 1603  2017                       0                 0                    12
# 1604  2017                       0                 0                     2
#
#       ADS  BCC  EC  GTI  LCC  RC  ...  Não contribui  Não sei responder.4  \
# 0       0   23   0    0    0   0  ...              2                    1
# 1       0   79   0    0    0   0  ...             12                    2
# 2       0   39   0    0    0   0  ...              1                    0
# 3       0   65   0    0    0   0  ...              8                    0
# 4       0   26   0    0    0   0  ...              4                    1
# ...   ...  ...  ..  ...  ...  ..  ...            ...                  ...
# 1600   18    0   0    0    0   0  ...              0                    0
# 1601   15    0   0    0    0   0  ...              2                    2
# 1602    0    0   0    0    0   3  ...              0                    0
# 1603   12    0   0    0    0   0  ...              1                    0
# 1604    0    0   0    0    2   0  ...              0                    0
#
#       nulos_Formacao  Muito boa  Boa  Regular  Fraca  Muito fraca  \
# 0                  1          7   10        5      0            0
# 1                 25         10   14       25      3            1
# 2                 10         10   10        8      0            0
# 3                 11         17   14       18      2            2
# 4                  0          6   12        7      1            0
# ...              ...        ...  ...      ...    ...          ...
# 1600               0          8    5        4      1            0
# 1601               0          5    2        7      0            1
# 1602               0          0    1        1      0            0
# 1603               0          4    2        6      0            0
# 1604               0          2    0        0      0            0
#
#       Não sei responder.5  Nota_Conceito_Faixa
# 0                       0                    3
# 1                       1                    4
# 2                       1                    4
# 3                       1                    3
# 4                       0                    5
# ...                   ...                  ...
# 1600                    0                    3
# 1601                    0                    4
# 1602                    1                    2
# 1603                    0                    3
# 1604                    0                    5
#
# [1605 rows x 227 columns]

# %%
df_2014
# Out:
#        Ano  Numero_Notas_Invalidas  Numero_Faltantes  Numero_Participantes  \
# 0     2014                       0                 4                    12
# 1     2014                       0                 4                    24
# 2     2014                       0                13                    43
# 3     2014                       0                 8                    29
# 4     2014                       0                 3                    37
# ...    ...                     ...               ...                   ...
# 1500  2014                       0                 1                    28
# 1501  2014                       0                 3                    20
# 1502  2014                       0                 4                    58
# 1503  2014                       0                 1                    22
# 1504  2014                       0                19                    26
#
#       ADS  BCC  EC  GTI  LCC  RC  ...  Não contribui  Não sei responder.4  \
# 0       0   16   0    0    0   0  ...              1                    0
# 1       0   28   0    0    0   0  ...              6                    0
# 2       0   56   0    0    0   0  ...              9                    0
# 3       0   37   0    0    0   0  ...              2                    0
# 4       0   40   0    0    0   0  ...              0                    0
# ...   ...  ...  ..  ...  ...  ..  ...            ...                  ...
# 1500    0    0   0    0   29   0  ...              0                    0
# 1501    0    0   0    0   23   0  ...              2                    0
# 1502    0    0   0    0   62   0  ...              2                    1
# 1503    0    0   0    0   23   0  ...              0                    1
# 1504    0    0   0    0   45   0  ...              5                    2
#
#       nulos_Formacao  Muito boa  Boa  Regular  Fraca  Muito fraca  \
# 0                  2          2    6        6      0            0
# 1                  2          6    6       10      2            2
# 2                 11         11   13       14      5            2
# 3                  6         10    9       11      0            1
# 4                  2         15   11       12      0            0
# ...              ...        ...  ...      ...    ...          ...
# 1500               0         13   10        5      0            1
# 1501               3          4    3       10      1            0
# 1502               0         40    9       10      1            0
# 1503               0         21    1        1      0            0
# 1504              14         14    3       10      3            1
#
#       Não sei responder.5  Nota_Conceito_Faixa
# 0                       0                    4
# 1                       0                    4
# 2                       0                    4
# 3                       0                    4
# 4                       0                    5
# ...                   ...                  ...
# 1500                    0                    3
# 1501                    2                    3
# 1502                    2                    2
# 1503                    0                    2
# 1504                    0                    3
#
# [1505 rows x 227 columns]

# %%
df_2011
# Out:
#        Ano  Numero_Notas_Invalidas  Numero_Faltantes  Numero_Participantes  \
# 0     2011                       0                12                    28
# 1     2011                       0                 3                    38
# 2     2011                       0                 3                    39
# 3     2011                       0                 4                    24
# 4     2011                       0                 1                    12
# ...    ...                     ...               ...                   ...
# 1217  2011                       1                 2                    58
# 1218  2011                       0                 1                     5
# 1219  2011                       0                 1                     8
# 1220  2011                       0                 0                     3
# 1221  2011                       0                 2                    35
#
#       ADS  BCC  EC  GTI  LCC  RC  ...  Não contribui  Não sei responder.4  \
# 0       0   40   0    0    0   0  ...              0                   13
# 1       0   41   0    0    0   0  ...              0                    2
# 2       0   42   0    0    0   0  ...              0                    1
# 3       0   28   0    0    0   0  ...              0                    4
# 4       0   13   0    0    0   0  ...              0                    1
# ...   ...  ...  ..  ...  ...  ..  ...            ...                  ...
# 1217    0   61   0    0    0   0  ...              0                    4
# 1218    6    0   0    0    0   0  ...              0                    1
# 1219    9    0   0    0    0   0  ...              0                    1
# 1220    3    0   0    0    0   0  ...              0                    0
# 1221   37    0   0    0    0   0  ...              0                    0
#
#       nulos_Formacao  Muito boa  Boa  Regular  Fraca  Muito fraca  \
# 0                  0          6   13        5      2            1
# 1                  0         21   17        1      0            0
# 2                  0         12   17        9      3            0
# 3                  0          8   11        4      1            0
# 4                  0          9    2        1      0            0
# ...              ...        ...  ...      ...    ...          ...
# 1217               0         14   26       15      2            1
# 1218               0          1    3        1      0            0
# 1219               0          3    4        0      0            1
# 1220               0          0    1        2      0            0
# 1221               0         11   17        6      3            0
#
#       Não sei responder.5  Nota_Conceito_Faixa
# 0                      13                    3
# 1                       2                    4
# 2                       1                    3
# 3                       4                    3
# 4                       1                    3
# ...                   ...                  ...
# 1217                    3                    3
# 1218                    1                    2
# 1219                    1                    4
# 1220                    0                    5
# 1221                    0                    5
#
# [1222 rows x 227 columns]

# %%
def contar_classes(dataset, classes):
    dict_ocorrencias = {}
    for classe in classes:
        numero_de_ocorrencias = dataset["Nota_Conceito_Faixa"].value_counts()[classe]
        dict_ocorrencias[f"{classe}"] = numero_de_ocorrencias
    return dict_ocorrencias

def mostrar_distribuicao(dataset, classes):
    dict_ocorrencias = contar_classes(dataset, classes)
    
    plt.style.use('_mpl-gallery')
    
    x = dict_ocorrencias.keys()
   
    y = dict_ocorrencias.values()
    
    fig, ax = plt.subplots(figsize=(5,3))
    
    bars = ax.bar(x, y, width=1, edgecolor="white")

    ax.bar_label(bars)

    ax.set(xlim=(-1, 5), xticks=np.arange(0, 5, 1),
           ylim=(0, 3500), yticks=np.arange(0, 3500, 500))
    
    plt.show()

# %%
mostrar_distribuicao(df_2021, [1,2,3,4,5])

# %%
mostrar_distribuicao(df_2017, [1,2,3,4,5])

# %%
mostrar_distribuicao(df_2014, [1,2,3,4,5])

# %%
mostrar_distribuicao(df_2011, [1,2,3,4,5])
