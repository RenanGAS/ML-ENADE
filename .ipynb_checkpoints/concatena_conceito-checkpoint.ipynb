# %%
import pandas as pd
import numpy as np

# %%
df_conceito = pd.read_csv('merge_tabelas_conceitos.csv')

# %%
df_conceito_faixa = df_conceito[['Nota_Conceito_Faixa']].copy()

# %%
df_conceito_faixa
# Out:
#       Nota_Conceito_Faixa
# 0                       3
# 1                       4
# 2                       4
# 3                       4
# 4                       4
# ...                   ...
# 5833                    3
# 5834                    2
# 5835                    4
# 5836                    5
# 5837                    5
#
# [5838 rows x 1 columns]

# %%
df_tabela_final = pd.read_csv('tabela_final_analise.csv')

# %%
df_tabela_final_treinamento = pd.concat([df_tabela_final, df_conceito_faixa], axis=1)

# %%
df_tabela_final_treinamento
# Out:
#        Ano  Numero_Notas_Invalidas  Numero_Faltantes  Numero_Participantes  \
# 0     2021                       1                 4                    36
# 1     2021                       0                27                    85
# 2     2021                       0                17                    82
# 3     2021                       0                12                    45
# 4     2021                       0                 4                    43
# ...    ...                     ...               ...                   ...
# 5833  2011                       1                 2                    58
# 5834  2011                       0                 1                     5
# 5835  2011                       0                 1                     8
# 5836  2011                       0                 0                     3
# 5837  2011                       0                 2                    35
#
#       ADS  BCC  EC  GTI  LCC  RC  ...  Não contribui  Não sei responder.4  \
# 0       0   41   0    0    0   0  ...              7                    2
# 1       0  112   0    0    0   0  ...             15                    3
# 2       0   99   0    0    0   0  ...              4                    0
# 3       0   57   0    0    0   0  ...              1                    2
# 4       0   47   0    0    0   0  ...              1                    0
# ...   ...  ...  ..  ...  ...  ..  ...            ...                  ...
# 5833    0   61   0    0    0   0  ...              0                    4
# 5834    6    0   0    0    0   0  ...              0                    1
# 5835    9    0   0    0    0   0  ...              0                    1
# 5836    3    0   0    0    0   0  ...              0                    0
# 5837   37    0   0    0    0   0  ...              0                    0
#
#       nulos_Formacao  Muito boa  Boa  Regular  Fraca  Muito fraca  \
# 0                  3          5   12       14      5            1
# 1                 11         25   28       38      5            2
# 2                 14         28   36       20      1            0
# 3                  0         19   21       15      2            0
# 4                  3         21   17        6      0            0
# ...              ...        ...  ...      ...    ...          ...
# 5833               0         14   26       15      2            1
# 5834               0          1    3        1      0            0
# 5835               0          3    4        0      0            1
# 5836               0          0    1        2      0            0
# 5837               0         11   17        6      3            0
#
#       Não sei responder.5  Nota_Conceito_Faixa
# 0                       1                    3
# 1                       3                    4
# 2                       0                    4
# 3                       0                    4
# 4                       0                    4
# ...                   ...                  ...
# 5833                    3                    3
# 5834                    1                    2
# 5835                    1                    4
# 5836                    0                    5
# 5837                    0                    5
#
# [5838 rows x 227 columns]

# %%
df_tabela_final_treinamento.to_csv('./{}.csv'.format('tabela_final_analise_conceito'),index=False)
