# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv('computacao_enade_2021.csv')

# %%
dados
# Out:
#        NU_ANO  CO_GRUPO  CO_UF_CURSO  CO_REGIAO_CURSO  CO_CATEGAD  CO_ORGACAD  \
# 0        2021      4004           51                5           1       10028
# 1        2021      4004           51                5           1       10028
# 2        2021      4004           51                5           1       10028
# 3        2021      4004           51                5           1       10028
# 4        2021      4004           51                5           1       10028
# ...       ...       ...          ...              ...         ...         ...
# 62026    2021        72           26                2           5       10022
# 62027    2021        72           26                2           5       10022
# 62028    2021        72           26                2           5       10022
# 62029    2021        72           26                2           5       10022
# 62030    2021        72           42                4           5       10022
#
# ...

# %%
dados["CO_GRUPO"].dtype # Ver se o formato Object pra string é válido
# Out:
# dtype('O')

# %%
dados.replace({'CO_GRUPO': {72: 'ADS', 4004: 'BCC', 6409: 'GTI', 4005: 'LCC', 79: 'RC', 4006: 'SI'}})
# Out:
#        NU_ANO CO_GRUPO  CO_UF_CURSO  CO_REGIAO_CURSO  CO_CATEGAD  CO_ORGACAD  \
# 0        2021      BCC           51                5           1       10028
# 1        2021      BCC           51                5           1       10028
# 2        2021      BCC           51                5           1       10028
# 3        2021      BCC           51                5           1       10028
# 4        2021      BCC           51                5           1       10028
# ...       ...      ...          ...              ...         ...         ...
# 62026    2021      ADS           26                2           5       10022
# 62027    2021      ADS           26                2           5       10022
# 62028    2021      ADS           26                2           5       10022
# 62029    2021      ADS           26                2           5       10022
# 62030    2021      ADS           42                4           5       10022
#
# ...

# %%
# dft1 = dft1.astype({"a": np.bool_, "c": np.float64})
dados = dados.astype({'CO_GRUPO':str})
