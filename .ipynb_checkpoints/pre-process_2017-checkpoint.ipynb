# %%
import pandas as pd
import numpy as np

# %%
dados_17 = pd.read_csv('computacao_enade_2017.csv')

# %%
dados_17

# %%
dados_17['CO_GRUPO'].dtype # Ver se o formato Object pra string é válido

# %%
dados_17.replace({'CO_GRUPO': {72: 'ADS', 4004: 'BCC', 4003: 'EC', 6409: 'GTI', 4005: 'LCC', 79: 'RC', 4006: 'SI'}}, inplace=True) # inplace=True permite que o df seja modificado diretamente

# dft1 = dft1.astype({"a": np.bool_, "c": np.float64})
dados_17 = dados_17.astype({'CO_GRUPO':str})

# %%
estado_dict = {
11 : 'RO',12 : 'AC', 
13 : 'AM',14 : 'RR',
15 : 'PA',16 : 'AP',
17 : 'TO',21 : 'MA',
22 : 'PI',23 : 'CE',
24 : 'RN',25 : 'PB',
26 : 'PE',27 : 'AL',
28 : 'SE',29 : 'BA',
31 : 'MG',32 : 'ES',
33 : 'RJ',35 : 'SP',
41 : 'PR',42 : 'SC',
43 : 'RS',50 : 'MS',
51 : 'MT',52 : 'GO', 
53 : 'DF'
}

# %%
dados_17['CO_UF_CURSO'].replace(estado_dict,inplace=True)
dados_17 = dados_17.astype({'CO_UF_CURSO':str})

# %%
regiao_dict = {
1 : 'N',2 : 'NE', 
3 : 'SE',4 : 'SUL',
5 : 'CO'
}

# %%
dados_17['CO_REGIAO_CURSO'].replace(regiao_dict,inplace=True)
dados_17 = dados_17.astype({'CO_REGIAO_CURSO':str})

# %%
# Há IESes do tipo especial

ies_especial = dados_17[dados_17["CO_CATEGAD"] == 7]
ies_especial
# Out:
#        NU_ANO CO_GRUPO CO_UF_CURSO CO_REGIAO_CURSO  CO_CATEGAD  CO_ORGACAD  \
# 8344     2017      BCC          SP              SE           7       10020
# 8345     2017      BCC          SP              SE           7       10020
# 8346     2017      BCC          SP              SE           7       10020
# 8347     2017      BCC          SP              SE           7       10020
# 8348     2017      BCC          SP              SE           7       10020
# ...       ...      ...         ...             ...         ...         ...
# 48617    2017      GTI          PE              NE           7       10022
# 48618    2017      GTI          PE              NE           7       10022
# 48619    2017      GTI          PE              NE           7       10022
# 48620    2017      GTI          PE              NE           7       10022
# 48621    2017      GTI          PE              NE           7       10022
#
#        CO_TURNO_GRADUACAO  NT_GER  ANO_FIM_EM  ANO_IN_GRAD  ... QE_I06 QE_I07  \
# 8344                  4.0    23.0      2013.0       2014.0  ...      B      B
# 8345                  4.0    35.9      2011.0       2012.0  ...      B    NaN
# 8346                  4.0    26.1      2012.0       2013.0  ...      B    NaN
# 8347                  4.0    34.3      2011.0       2012.0  ...    NaN      C
# 8348                  4.0    32.4      2009.0       2010.0  ...    NaN      D
# ...                   ...     ...         ...          ...  ...    ...    ...
# 48617                 4.0    63.2      1997.0       2015.0  ...      D      C
# 48618                 4.0     NaN      2005.0       2015.0  ...      B      B
# 48619                 4.0    64.4      2010.0       2015.0  ...      C      C
# 48620                 4.0    36.1      2007.0       2015.0  ...      B      D
# 48621                 4.0    43.9      2011.0       2015.0  ...      C      G
#
#        QE_I15 QE_I10 QE_I22 QE_I23 QE_I61 QE_I62 QE_I38 QE_I27
# 8344      NaN      E    NaN      C    6.0    6.0    5.0    6.0
# 8345        A      E      C      B    NaN    NaN    NaN    NaN
# 8346        A    NaN      B      B    6.0    6.0    5.0    3.0
# 8347        A      A    NaN      C    6.0    6.0    4.0    6.0
# 8348      NaN    NaN    NaN      B    NaN    NaN    NaN    NaN
# ...       ...    ...    ...    ...    ...    ...    ...    ...
# 48617       A      E      B      B    5.0    5.0    5.0    5.0
# 48618       A      E      C      B    6.0    4.0    1.0    5.0
# 48619       A      E      C      B    3.0    2.0    4.0    5.0
# 48620       A      B      C      B    6.0    6.0    6.0    5.0
# 48621     NaN      B      D      B    3.0    4.0    4.0    5.0
#
# [210 rows x 29 columns]

# %%
cat_adm_dict = {
1 : 'Pública Federal',2 : 'Pública Estadual', 
3 : 'Pública Municipal',4 : 'Privada CFL',
5 : 'Privada SFL', 7 : 'Especial'
}

# %%
dados_17['CO_CATEGAD'].replace(cat_adm_dict,inplace=True)
dados_17 = dados_17.astype({'CO_CATEGAD':str})

# %%
# cefet = dados_17[dados_17['CO_ORGACAD'] == 10019]
# cefet

cat_org_dict = {
10019 : 'CEFET',10020 : 'Centro Universitário', 
10022 : 'Faculdade',10026 : 'IFECT',
10028 : 'Universidade'
}

# %%
dados_17['CO_ORGACAD'].replace(cat_org_dict,inplace=True)
dados_17 = dados_17.astype({'CO_ORGACAD':str})

# %%
turno_dict = {
1 : 'Matutino',2 : 'Vespertino', 
3 : 'Integral',4 : 'Noturno'
}

# %%
dados_17['CO_TURNO_GRADUACAO'].replace(turno_dict,inplace=True)
dados_17 = dados_17.astype({'CO_TURNO_GRADUACAO':str})

# %%
# Análise dos atributos ANO_FIM_EM e ANO_IN_GRAD

# %%
outliers_afem = dados_17[(dados_17['ANO_FIM_EM'] < 1951) | (dados_17['ANO_FIM_EM'] > 2021)]
outliers_afem

outliers_aig = dados_17[(dados_17['ANO_IN_GRAD'] < 1971) | (dados_17['ANO_IN_GRAD'] > 2017)]
outliers_aig

# %%
media_afem = dados_17['ANO_FIM_EM'].mean()
media_afem

media_aig = dados_17['ANO_IN_GRAD'].mean()
media_aig

# %%
#-------------------------------#

# %%
tipo_em_dict = {
'A' : 'Pública','B' : 'Privada', 
'C' : 'Exterior', 'D' : 'Maior parte pública',
'E':'Maior parte privada', 'F': 'Brasil e exterior'
}

# %%
dados_17['QE_I17'].replace(tipo_em_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I17':str})

# %%
mod_em_dict = {
'A' : 'Tradicional','B' : 'Técnico', 
'C' : 'Magistério', 'D' : 'Supletivo',
'E':'Outra'
}

# %%
dados_17['QE_I18'].replace(mod_em_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I18':str})

# %%
dados_17[['QE_I17', 'QE_I18', 'QE_I02']]

# %%
dados_17

# %%
raca_dict = {
'A' : 'Branca','B' : 'Preta', 
'C' : 'Amarela', 'D' : 'Parda',
'E': 'Indígena', 'F': 'Não declarado'
}

# %%
dados_17['QE_I02'].replace(raca_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I02':str})

# %%
est_civil_dict = {
'A' : 'Solteiro','B' : 'Casado', 
'C' : 'Separado', 'D' : 'Viúvo',
'E': 'Outro'
}

# %%
dados_17['QE_I01'].replace(est_civil_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I01':str})

# %%
nl_pai_mae_dict = {
'A' : 'Nenhuma','B' : 'Fundamental 1-5', 
'C' : 'Fundamental 6-9', 'D' : 'Médio',
'E': 'Superior', 'F': 'Pós-graduação'
}

# %%
dados_17['QE_I04'].replace(nl_pai_mae_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I04':str})

# %%
dados_17['QE_I05'].replace(nl_pai_mae_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I05':str})

# %%
renda_dict = {
'A' : 'Até 1,5 SM','B' : 'De 1,5 a 3 SM', 
'C' : 'De 3 a 4,5 SM', 'D' : 'De 4,5 a 6 SM',
'E': 'De 6 a 10 SM', 'F': 'De 10 a 30 SM',
'G': 'Acima de 30 SM'
}

# %%
dados_17['QE_I08'].replace(renda_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I08':str})

# %%
moradia_dict = {
'A' : 'Sozinho','B' : 'Parentes', 
'C' : 'Cônjuge/Filhos', 'D' : 'Outras pessoas',
'E': 'Universidade', 'F': 'Habitação individual/coletiva'
}

# %%
dados_17['QE_I06'].replace(moradia_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I06':str})

# %%
qtde_moradia_dict = {
'A' : 'Nenhuma','B' : 'Uma', 
'C' : 'Duas', 'D' : 'Três',
'E': 'Quatro', 'F': 'Cinco',
'G': 'Seis', 'H': 'Sete ou mais'
}

# %%
dados_17['QE_I07'].replace(qtde_moradia_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I07':str})

# %%
politica_dict = {
'A' : 'Não','B' : 'Critério étnico-racial',
'C' : 'Critério de renda', 'D' : 'Bolsa de estudos',
'E': 'Combinação de critérios', 'F': 'Critérios diferentes'
}

# %%
dados_17['QE_I15'].replace(politica_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I15':str})

# %%
trabalho_dict = {
'A' : 'Não','B' : 'Eventualmente',
'C' : 'Até 20 horas', 'D' : '21 a 39 horas',
'E': '40 horas ou mais'
}

# %%
dados_17['QE_I10'].replace(trabalho_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I10':str})

# %%
qtde_livros_dict = {
'A' : 'Nenhum','B' : '1 ou 2',
'C' : '3-5', 'D' : '6-8',
'E': '+8'
}

# %%
dados_17['QE_I22'].replace(qtde_livros_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I22':str})

# %%
horas_estudo_dict = {
'A' : 'Nenhum','B' : '1 ou 2',
'C' : '3-5', 'D' : '6-8',
'E': '+8'
}

# %%
dados_17['QE_I23'].replace(horas_estudo_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I23':str})

# %%
cond_salas_dict = {
    1 : 'Discordo totalmente',
    2 : 'Discordo',
    3 : 'Discordo parcialmente',
    4 : 'Concordo parcialmente',
    5 : 'Concordo',
    6 : 'Concordo totalmente',
    7 : 'Não sei responder',
    8 : 'Não se aplica'
}

# %%
dados_17['QE_I61'].replace(cond_salas_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I61':str})

# %%
cond_praticas_dict = {
    1 : 'Discordo totalmente',
    2 : 'Discordo',
    3 : 'Discordo parcialmente',
    4 : 'Concordo parcialmente',
    5 : 'Concordo',
    6 : 'Concordo totalmente',
    7 : 'Não sei responder',
    8 : 'Não se aplica'
}

# %%
dados_17['QE_I62'].replace(cond_praticas_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I62':str})

# %%
plano_ensino_dict = {
    1 : 'Discordo totalmente',
    2 : 'Discordo',
    3 : 'Discordo parcialmente',
    4 : 'Concordo parcialmente',
    5 : 'Concordo',
    6 : 'Concordo totalmente',
    7 : 'Não sei responder',
    8 : 'Não se aplica'
}

# %%
dados_17['QE_I38'].replace(plano_ensino_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I38':str})

# %%
formacao_dict = {
    1 : 'Discordo totalmente',
    2 : 'Discordo',
    3 : 'Discordo parcialmente',
    4 : 'Concordo parcialmente',
    5 : 'Concordo',
    6 : 'Concordo totalmente',
    7 : 'Não sei responder',
    8 : 'Não se aplica'
}

# %%
dados_17['QE_I27'].replace(formacao_dict,inplace=True)
dados_17 = dados_17.astype({'QE_I27':str})

# %%
dados_17
# Out:
#        NU_ANO CO_GRUPO CO_UF_CURSO CO_REGIAO_CURSO       CO_CATEGAD  \
# 0        2017      BCC          MT              CO  Pública Federal
# 1        2017      BCC          MT              CO  Pública Federal
# 2        2017      BCC          MT              CO  Pública Federal
# 3        2017      BCC          MT              CO  Pública Federal
# 4        2017      BCC          MT              CO  Pública Federal
# ...       ...      ...         ...             ...              ...
# 51004    2017      ADS          SC             SUL      Privada SFL
# 51005    2017      ADS          SC             SUL      Privada SFL
# 51006    2017      ADS          SC             SUL      Privada SFL
# 51007    2017      LCC          SC             SUL      Privada SFL
# 51008    2017      LCC          SC             SUL      Privada SFL
#
#          CO_ORGACAD CO_TURNO_GRADUACAO  NT_GER  ANO_FIM_EM  ANO_IN_GRAD  ...  \
# 0      Universidade           Integral    25.4      2012.0       2014.0  ...
# 1      Universidade           Integral    44.4      2012.0       2014.0  ...
# 2      Universidade           Integral    23.0      2014.0       2014.0  ...
# 3      Universidade           Integral    53.2      2012.0       2013.0  ...
# 4      Universidade           Integral    22.4      2012.0       2013.0  ...
# ...             ...                ...     ...         ...          ...  ...
# 51004     Faculdade           Matutino    26.9      1996.0       2014.0  ...
# 51005     Faculdade           Matutino    30.6      2005.0       2015.0  ...
# 51006     Faculdade           Matutino    43.8      2007.0       2015.0  ...
# 51007  Universidade           Integral    51.1      2009.0       2015.0  ...
# 51008  Universidade           Integral    52.0      2000.0       2015.0  ...
#
#                QE_I06        QE_I07                QE_I15            QE_I10  \
# 0            Parentes       Nenhuma                   Não  40 horas ou mais
# 1            Parentes           nan  Critérios diferentes               Não
# 2            Parentes       Nenhuma      Bolsa de estudos               Não
# 3            Parentes  Sete ou mais                   Não               Não
# 4            Parentes           Uma      Bolsa de estudos               Não
# ...               ...           ...                   ...               ...
# 51004  Cônjuge/Filhos          Duas                   Não     21 a 39 horas
# 51005  Cônjuge/Filhos       Nenhuma                   Não               Não
# 51006        Parentes        Quatro                   Não  40 horas ou mais
# 51007         Sozinho          Três                   Não               Não
# 51008        Parentes           Uma                   Não  40 horas ou mais
#
#        QE_I22  QE_I23                 QE_I61                 QE_I62  \
# 0      Nenhum     nan               Concordo               Concordo
# 1      1 ou 2     3-5    Concordo totalmente    Concordo totalmente
# 2         6-8     3-5  Concordo parcialmente               Concordo
# 3         3-5     3-5    Discordo totalmente    Discordo totalmente
# 4         nan     3-5               Concordo  Concordo parcialmente
# ...       ...     ...                    ...                    ...
# 51004  Nenhum  1 ou 2    Concordo totalmente    Concordo totalmente
# 51005  Nenhum  1 ou 2    Concordo totalmente    Concordo totalmente
# 51006  1 ou 2     6-8               Concordo    Concordo totalmente
# 51007      +8     3-5    Concordo totalmente    Concordo totalmente
# 51008     3-5     3-5      Não sei responder    Concordo totalmente
#
#                       QE_I38                 QE_I27
# 0      Concordo parcialmente    Concordo totalmente
# 1        Concordo totalmente    Concordo totalmente
# 2      Discordo parcialmente  Discordo parcialmente
# 3                   Concordo    Concordo totalmente
# 4      Concordo parcialmente  Concordo parcialmente
# ...                      ...                    ...
# 51004               Concordo    Concordo totalmente
# 51005               Discordo  Concordo parcialmente
# 51006               Concordo  Concordo parcialmente
# 51007    Concordo totalmente    Concordo totalmente
# 51008    Concordo totalmente    Concordo totalmente
#
# [51009 rows x 29 columns]

# %%
columns_dict = {
    "NU_ANO": "Ano",
    "CO_GRUPO": "Curso",
    "CO_UF_CURSO": "UF",
    "CO_REGIAO_CURSO": "Regiao",
    "CO_CATEGAD": "Cat_Administrativa",
    "CO_ORGACAD": "Cat_Org_Academica",
    "CO_TURNO_GRADUACAO": "Turno",
    "NT_GER": "Nota_Geral",
    "ANO_FIM_EM": "Conclusao_Ensino_Medio",
    "ANO_IN_GRAD": "Inicio_Graduacao",
    "QE_I17": "Tipo_Escola_EM",
    "QE_I18": "Modalidade_EM",
    "NU_IDADE": "Idade",
    "TP_SEXO": "Sexo",
    "QE_I02": "Cor_Raca",
    "QE_I01": "Estado_Civil",
    "QE_I04": "Nl_Pai",
    "QE_I05": "Nl_Mae",
    "QE_I08": "Renda",
    "QE_I06": "Moradia",
    "QE_I07": "Qtde_Pessoas",
    "QE_I15": "Politica_de_Ingresso",
    "QE_I10": "Situacao_Trabalho",
    "QE_I22": "Qtde_Livros",
    "QE_I23": "Horas_de_Estudo",
    "QE_I61": "Condicao_Salas",
    "QE_I62": "Condicao_Praticas",
    "QE_I38": "Plano_de_Ensino",
    "QE_I27": "Formacao"
}

# %%
dados_17.rename(columns = columns_dict, inplace = True)

# %%
dados_17
# Out:
#         Ano Curso  UF Regiao Cat_Administrativa Cat_Org_Academica     Turno  \
# 0      2017   BCC  MT     CO    Pública Federal      Universidade  Integral
# 1      2017   BCC  MT     CO    Pública Federal      Universidade  Integral
# 2      2017   BCC  MT     CO    Pública Federal      Universidade  Integral
# 3      2017   BCC  MT     CO    Pública Federal      Universidade  Integral
# 4      2017   BCC  MT     CO    Pública Federal      Universidade  Integral
# ...     ...   ...  ..    ...                ...               ...       ...
# 51004  2017   ADS  SC    SUL        Privada SFL         Faculdade  Matutino
# 51005  2017   ADS  SC    SUL        Privada SFL         Faculdade  Matutino
# 51006  2017   ADS  SC    SUL        Privada SFL         Faculdade  Matutino
# 51007  2017   LCC  SC    SUL        Privada SFL      Universidade  Integral
# 51008  2017   LCC  SC    SUL        Privada SFL      Universidade  Integral
#
#        Nota_Geral  Conclusao_Ensino_Medio  Inicio_Graduacao  ...  \
# 0            25.4                  2012.0            2014.0  ...
# 1            44.4                  2012.0            2014.0  ...
# 2            23.0                  2014.0            2014.0  ...
# 3            53.2                  2012.0            2013.0  ...
# 4            22.4                  2012.0            2013.0  ...
# ...           ...                     ...               ...  ...
# 51004        26.9                  1996.0            2014.0  ...
# 51005        30.6                  2005.0            2015.0  ...
# 51006        43.8                  2007.0            2015.0  ...
# 51007        51.1                  2009.0            2015.0  ...
# 51008        52.0                  2000.0            2015.0  ...
#
#               Moradia  Qtde_Pessoas  Politica_de_Ingresso Situacao_Trabalho  \
# 0            Parentes       Nenhuma                   Não  40 horas ou mais
# 1            Parentes           nan  Critérios diferentes               Não
# 2            Parentes       Nenhuma      Bolsa de estudos               Não
# 3            Parentes  Sete ou mais                   Não               Não
# 4            Parentes           Uma      Bolsa de estudos               Não
# ...               ...           ...                   ...               ...
# 51004  Cônjuge/Filhos          Duas                   Não     21 a 39 horas
# 51005  Cônjuge/Filhos       Nenhuma                   Não               Não
# 51006        Parentes        Quatro                   Não  40 horas ou mais
# 51007         Sozinho          Três                   Não               Não
# 51008        Parentes           Uma                   Não  40 horas ou mais
#
#       Qtde_Livros Horas_de_Estudo         Condicao_Salas  \
# 0          Nenhum             nan               Concordo
# 1          1 ou 2             3-5    Concordo totalmente
# 2             6-8             3-5  Concordo parcialmente
# 3             3-5             3-5    Discordo totalmente
# 4             nan             3-5               Concordo
# ...           ...             ...                    ...
# 51004      Nenhum          1 ou 2    Concordo totalmente
# 51005      Nenhum          1 ou 2    Concordo totalmente
# 51006      1 ou 2             6-8               Concordo
# 51007          +8             3-5    Concordo totalmente
# 51008         3-5             3-5      Não sei responder
#
#            Condicao_Praticas        Plano_de_Ensino               Formacao
# 0                   Concordo  Concordo parcialmente    Concordo totalmente
# 1        Concordo totalmente    Concordo totalmente    Concordo totalmente
# 2                   Concordo  Discordo parcialmente  Discordo parcialmente
# 3        Discordo totalmente               Concordo    Concordo totalmente
# 4      Concordo parcialmente  Concordo parcialmente  Concordo parcialmente
# ...                      ...                    ...                    ...
# 51004    Concordo totalmente               Concordo    Concordo totalmente
# 51005    Concordo totalmente               Discordo  Concordo parcialmente
# 51006    Concordo totalmente               Concordo  Concordo parcialmente
# 51007    Concordo totalmente    Concordo totalmente    Concordo totalmente
# 51008    Concordo totalmente    Concordo totalmente    Concordo totalmente
#
# [51009 rows x 29 columns]

# %%
dados_17.to_csv('./{}.csv'.format('pre-process_2017'),index=False)

# %%
# Gráfico do número de alunos de cada curso

# %%
count_bcc = dados_17[dados_17['Curso'] == 'BCC']['Curso'].count()
count_ads = dados_17[dados_17['Curso'] == 'ADS']['Curso'].count()
count_gti = dados_17[dados_17['Curso'] == 'GTI']['Curso'].count()
count_ec = dados_17[dados_17['Curso'] == 'EC']['Curso'].count()
count_lcc = dados_17[dados_17['Curso'] == 'LCC']['Curso'].count()
count_rc = dados_17[dados_17['Curso'] == 'RC']['Curso'].count()
count_si = dados_17[dados_17['Curso'] == 'SI']['Curso'].count()

# %%
count_array = [count_bcc,count_ads, count_gti, count_ec, 
               count_lcc, count_rc, count_si]

# %%
count_courses = pd.DataFrame({'Número de alunos': count_array}, index=['BCC', 'ADS', 'GTI', 'EC', 'LCC', 'RC', 'SI'])

count_courses.plot.bar();
